# %%
# %pip install pandas matplotlib numpy
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yashpaul/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/yashpaul/Library/Python/3.11/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: six>=1.5 in /Users/yashpaul/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load dataset
data = pd.read_csv('data_training_selected_clusters_comments_and_rules.csv')
data.head()
data.describe()
# Out:
#              body                        target_reason  \
# count       32966                                32966
# unique      30921                                  269
# top     [deleted]  incivility, overly cruel or hostile
# freq          872                                 7038
#
#                                        target_description  \
# count                                               32877
# unique                                                336
# top     attack ideas, not people. the purpose of this ...
# freq                                                 7038
#
#                                        public_description subreddit_id  \
# count                                               32945        32966
# unique                                                328          334
# top     A catharsis for the frustrated moral philosoph...     t5_2xhvq
# freq                                                 7038         7038
#
#        assigned_rule_cluster          label
# count                  32966          32966
# unique                    17              2
# top                   C - 14  non_violation
# freq                    8796          17506
